# %% [markdown]
# # 8 Ways To Filter a Pandas DataFrame by a Partial String or Pattern
# We will use functions such as Series.isin() and Series.str.contains() to filter the data. I minimized the use of apply() and Lambda functions
#
# source: https://towardsdatascience.com/8-ways-to-filter-a-pandas-dataframe-by-a-partial-string-or-pattern-49f43279c50f?utm_source=pocket_mylist or https://shecancode.io/blog/filter-a-pandas-dataframe-by-a-partial-string-or-pattern-in-8-ways

# %%
import pandas as pd
data = pd.read_csv('Data/netflix_titles.csv')
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# 1. Filter rows that match a given String in a column

# %%
mask = data['type'].isin(['TV Show']) 

#display the mask   
mask.head()
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# Name: type, dtype: bool

# %%
data[mask].head()
# Out:
#   show_id     type                  title         director  \
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
# 5      s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 3                                                NaN           NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...           NaN
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
# 5  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...
# 5  The arrival of a charismatic young priest brin...

# %%
data.loc[mask, ['title','country','duration']]
# Out:
#                       title                                        country  \
# 1             Blood & Water                                   South Africa
# 2                 Ganglands                                            NaN
# 3     Jailbirds New Orleans                                            NaN
# 4              Kota Factory                                          India
# 5             Midnight Mass                                            NaN
# ...                     ...                                            ...
# 8795        Yu-Gi-Oh! Arc-V                                  Japan, Canada
# 8796             Yunus Emre                                         Turkey
# 8797              Zak Storm  United States, France, South Korea, Indonesia
# 8800     Zindagi Gulzar Hai                                       Pakistan
# 8803            Zombie Dumb                                            NaN
#
#        duration
# 1     2 Seasons
# 2      1 Season
# 3      1 Season
# 4     2 Seasons
# 5      1 Season
# ...         ...
# 8795  2 Seasons
# 8796  2 Seasons
# 8797  3 Seasons
# 8800   1 Season
# 8803  2 Seasons
#
# [2676 rows x 3 columns]

# %% [markdown]
# 2. Filter rows where a partial string is present

# %%
mask = data['listed_in'].str.contains('horror', case=False, na=False)
data[mask].sample(3)
#data[mask].head()
# Out:
#      show_id     type             title        director  \
# 5092   s5093  TV Show  Devilman Crybaby   Masaaki Yuasa
# 2409   s2410  TV Show         Reality Z             NaN
# 6423   s6424    Movie            Carrie  Brian De Palma
#
#                                                    cast        country  \
# 5092  Kouki Uchiyama, Ayumu Murase, Megumi Han, Ami ...          Japan
# 2409  Ana Hartmann, Sabrina Sato, Luellem de Castro,...         Brazil
# 6423  Sissy Spacek, Piper Laurie, Amy Irving, Willia...  United States
#
#            date_added  release_year rating  duration  \
# 5092  January 5, 2018          2018  TV-MA  1 Season
# 2409    June 10, 2020          2020  TV-MA  1 Season
# 6423     June 1, 2019          1976      R    98 min
#
#                                             listed_in  \
# 5092  Anime Series, International TV Shows, TV Horror
# 2409  International TV Shows, TV Horror, TV Mysteries
# 6423       Classic Movies, Cult Movies, Horror Movies
#
#                                             description
# 5092  With demons reawakened and humanity in turmoil...
# 2409  With Rio de Janeiro under a zombie attack, rea...
# 6423  An outcast teen with telekinetic ability lashe...

# %%
#use starts with
mask = data['country'].str.startswith('Jap', na=False)
data[mask].sample(3)
# Out:
#      show_id     type                                     title  \
# 56       s57    Movie  Naruto Shippuden the Movie: Blood Prison
# 2945   s2946  TV Show                Cagaster of an Insect Cage
# 2065   s2066    Movie                       Children of the Sea
#
#              director                                               cast  \
# 56    Masahiko Murata  Junko Takeuchi, Chie Nakamura, Rikiya Koyama, ...
# 2945              NaN  Yoshimasa Hosoya, Kana Hanazawa, Natsuki Hanae...
# 2065   Ayumu Watanabe  Mana Ashida, Hiiro Ishibashi, Seishu Uragami, ...
#
#                    country          date_added  release_year rating  duration  \
# 56                   Japan  September 15, 2021          2011  TV-14   102 min
# 2945                 Japan    February 6, 2020          2020  TV-MA  1 Season
# 2065  Japan, United States   September 1, 2020          2019  TV-PG   112 min
#
#                                               listed_in  \
# 56    Action & Adventure, Anime Features, Internatio...
# 2945               Anime Series, International TV Shows
# 2065               Anime Features, International Movies
#
#                                             description
# 56    Mistakenly accused of an attack on the Fourth ...
# 2945  Thirty years after a disease that turns the in...
# 2065  Ruka spends her summer at the aquarium, where ...

# %% [markdown]
# 3. Filter rows with either of two partial strings (OR)

# %%
pattern = 'horror|stand-up'
mask = data['listed_in'].str.contains(pattern, case=False, na=False)
data[mask].sample(3)
# Out:
#      show_id   type                              title  \
# 7998   s7999  Movie                        Shark Night
# 1249   s1250  Movie    Blanche Gardin: The All-Nighter
# 5878   s5879  Movie  Mike Epps: Don't Take It Personal
#
#                                  director  \
# 7998                       David R. Ellis
# 1249  Xavier Maingon, Marc-Antoine Hélard
# 5878                           L. Frazier
#
#                                                    cast        country  \
# 7998  Sara Paxton, Dustin Milligan, Chris Carmack, K...  United States
# 1249                                     Blanche Gardin            NaN
# 5878                                          Mike Epps  United States
#
#              date_added  release_year rating duration        listed_in  \
# 7998   November 2, 2019          2011  PG-13   91 min    Horror Movies
# 1249      March 1, 2021          2021  TV-MA   96 min  Stand-Up Comedy
# 5878  December 18, 2015          2015  TV-MA   60 min  Stand-Up Comedy
#
#                                             description
# 7998  A weekend of beach-house debauchery turns into...
# 1249  With self-deprecating humor, French comic Blan...
# 5878  Mike Epps tears up the stage at L.A.'s histori...

# %% [markdown]
# 4. FILTER ROWS WHERE BOTH STRINGS ARE PRESENT (AND)

# %%
pattern = 'states.*mexico'
mask = data['country'].str.contains(pattern, case=False, na=False)
data[mask].head()
# Out:
#      show_id     type                         title                director  \
# 134     s135    Movie      Clear and Present Danger           Phillip Noyce
# 332     s333    Movie                 Deep Blue Sea            Renny Harlin
# 1027   s1028    Movie                  Crimson Peak      Guillermo del Toro
# 1146   s1147  TV Show        Haunted: Latin America  Adrián García Bogliano
# 1549   s1550    Movie  The Professor and the Madman          Farhad Safinia
#
#                                                    cast  \
# 134   Harrison Ford, Willem Dafoe, Anne Archer, Joaq...
# 332   Thomas Jane, Saffron Burrows, Samuel L. Jackso...
# 1027  Mia Wasikowska, Jessica Chastain, Tom Hiddlest...
# 1146                                                NaN
# 1549  Mel Gibson, Sean Penn, Natalie Dormer, Eddie M...
#
#                                                 country         date_added  \
# 134                               United States, Mexico  September 1, 2021
# 332                               United States, Mexico     August 1, 2021
# 1027                      Canada, United States, Mexico     April 16, 2021
# 1146                              United States, Mexico     March 31, 2021
# 1549  Ireland, France, Iceland, United States, Mexic...  December 15, 2020
#
#       release_year rating  duration  \
# 134           1994  PG-13   142 min
# 332           1999      R   105 min
# 1027          2015      R   119 min
# 1146          2021  TV-14  1 Season
# 1549          2019  TV-14   125 min
#
#                                               listed_in  \
# 134                          Action & Adventure, Dramas
# 332   Action & Adventure, Horror Movies, Sci-Fi & Fa...
# 1027   Horror Movies, Romantic Movies, Sci-Fi & Fantasy
# 1146  International TV Shows, Reality TV, Spanish-La...
# 1549                         Dramas, Independent Movies
#
#                                             description
# 134   When the president's friend is murdered, CIA D...
# 332   Scientists conduct research on sharks in searc...
# 1027  After marrying a mysterious British aristocrat...
# 1146  Real people's terrifying tales of the chilling...
# 1549  While working on the first Oxford English Dict...

# %% [markdown]
# 5. Filter rows with numbers in a particular column

# %%
pattern = '-[0-9]'
mask = data['rating'].str.contains(pattern, na=False)
data[mask].sample(3)
# Out:
#      show_id     type                    title  \
# 3443   s3444    Movie            Love for Sale
# 2946   s2947    Movie        Gardeners of Eden
# 5030   s5031  TV Show  Hitler's Circle of Evil
#
#                                director  \
# 3443                 Andibachtiar Yusuf
# 2946  Austin Peck, Anneliese Vandenberg
# 5030                                NaN
#
#                                                    cast               country  \
# 3443  Gading Marten, Della Dartyan, Rukman Rosadi, A...             Indonesia
# 2946  Kristin Davis, Daphne Sheldrick, Nick Trent, J...  Kenya, United States
# 5030  Alisdair Simpson, Henrik Jørgensen, James Lowe...        United Kingdom
#
#              date_added  release_year rating  duration  \
# 3443    October 6, 2019          2018  TV-14   101 min
# 2946   February 6, 2020          2014  TV-14    70 min
# 5030  February 22, 2018          2017  TV-14  1 Season
#
#                                               listed_in  \
# 3443      Dramas, International Movies, Romantic Movies
# 2946                                      Documentaries
# 5030  British TV Shows, Docuseries, International TV...
#
#                                             description
# 3443  Richard accepts a bet that he can't find a com...
# 2946  As corrupt governments fail to stop the slaugh...
# 5030  Surviving power struggles, betrayals and plots...

# %% [markdown]
# 6. Filter rows where a partial string is present in multiple columns

# %%
mask1 = data['rating'].str.contains('tv', case=False, na=False)
mask2 = data['listed_in'].str.contains('tv', case=False, na=False)
mask3 = data['type'].str.contains('tv', case=False, na=False)
data[mask1 & mask2 & mask3].head()
# Out:
#   show_id     type                  title         director  \
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
# 5      s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 3                                                NaN           NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...           NaN
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
# 5  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...
# 5  The arrival of a charismatic young priest brin...

# %% [markdown]
# 7. Filter for rows where values in one column are present in another column.

# %%
#mask = data.apply(lambda x: str(x[’director’]) in str(x[’cast’]), axis=1)
#data[mask].head()
