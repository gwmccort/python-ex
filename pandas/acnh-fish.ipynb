# %% [markdown]
# Read ACNH material list in tab seperated files, data files cut from web pages on http://acnh.co

# %%
import pandas as pd

# fish = pd.read_csv('Data/fish.tsv', sep='\t', lineterminator='\n')
fish = pd.read_csv('Data/fish.tsv', sep='\t')
fish
# Out:
#                 Item Category Subcategory          Particularity  Sales Price  \
# 0            Anchovy     Fish    Sea Fish           Small shadow          200
# 1          Angelfish     Fish  River Fish           Small shadow         3000
# 2           Arapaima     Fish  River Fish            Huge shadow        10000
# 3            Arowana     Fish  River Fish           Large shadow        10000
# 4    Barred Knifejaw     Fish    Sea Fish          Medium shadow         5000
# ..               ...      ...         ...                    ...          ...
# 75           Tilapia     Fish  River Fish          Medium shadow          800
# 76              Tuna     Fish   Pier Fish            Huge shadow         7000
# 77       Whale Shark     Fish    Sea Fish  Large shadow with fin        13000
# 78      Yellow Perch     Fish  River Fish          Medium shadow          300
# 79  Zebra Turkeyfish     Fish    Sea Fish          Medium shadow          500
#
#     Drop-Off Box   C.J.
# ...

# %%
bugs = pd.read_csv('Data/bugs.tsv', sep='\t')
bugs
# Out:
#                 Item Category           Subcategory  \
# 0   Agrias Butterfly      Bug            Flying Bug
# 1                Ant      Bug            Ground Bug
# 2         Atlas Moth      Bug              Tree Bug
# 3            Bagworm      Bug              Tree Bug
# 4   Banded Dragonfly      Bug            Flying Bug
# ..               ...      ...                   ...
# 75      Walking Leaf      Bug              Tree Bug
# 76     Walking Stick      Bug              Tree Bug
# 77              Wasp      Bug              Tree Bug
# 78       Wharf Roach      Bug  Beach Bug / Rock Bug
# 79  Yellow Butterfly      Bug            Flying Bug
#
#                       Particularity Sales price Drop-Off Box Flick
# 0                               NaN        3000         2400  4500
# 1                    On rotten food          80           64   120
# 2                               NaN        3000         2400  4500
# 3                     Shaking trees         600          480   900
# ...
