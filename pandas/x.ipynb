# %%
import pandas as pd

# %%
# df = pd.read_csv('Data/Sams-New-Transaction.csv')
df = pd.read_csv('Data/transactions.csv')
df.head()
# Out:
#         Date                  Description  \
# 0  2/22/2022                       Amazon
# 1  2/21/2022  RUBEN ALLEN FB CA4029357733
# 2  2/21/2022  RACHELAUCHI FB CA4029357733
# 3  2/21/2022                       Amazon
# 4  2/21/2022                   McDonald's
#
#                   Original Description  Amount Transaction Type   Category  \
# 0         AMZN Mktp US WAAmzn.com/bill    7.48            debit   Shopping
# 1  PAYPAL *RUBEN ALLEN FB CA4029357733   13.63            debit    Charity
# 2  PAYPAL *RACHELAUCHI FB CA4029357733   20.05            debit    Charity
# 3         AMZN Mktp US WAAmzn.com/bill    7.38            debit   Shopping
# 4      MCDONALD'S M2058 IACEDAR RAPIDS   12.39            debit  Fast Food
#
#                                         Account Name  Labels  Notes
# 0  Sam's Club&amp;#XX4; World Elite Mastercard&am...     NaN    NaN
# 1  Sam's Club&amp;#XX4; World Elite Mastercard&am...     NaN    NaN
# ...

# %%
df[['month','day','year']] = df['Date'].str.split('/', expand=True)
df
# Out:
#            Date                                        Description  \
# 0     2/22/2022                                             Amazon
# 1     2/21/2022                        RUBEN ALLEN FB CA4029357733
# 2     2/21/2022                        RACHELAUCHI FB CA4029357733
# 3     2/21/2022                                             Amazon
# 4     2/21/2022                                         McDonald's
# ...         ...                                                ...
# 1308  4/09/2021  SHORT-TERM CAP GAIN STRATEGIC ADVISERS INTERNA...
# 1309  4/09/2021  LONG-TERM CAP GAIN STRATEGIC ADVISERS SMALL-MI...
# 1310  4/09/2021  REINVESTMENT STRATEGIC ADVISERS CORE INCOME FU...
# 1311  4/09/2021  REINVESTMENT STRATEGIC ADVISERS SMALL-MID CAP ...
# 1312  4/09/2021  LONG-TERM CAP GAIN FIDELITY SAI US TREASURY BO...
#
#                                    Original Description   Amount  \
# 0                          AMZN Mktp US WAAmzn.com/bill     7.48
# ...
